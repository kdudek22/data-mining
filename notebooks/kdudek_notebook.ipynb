# %%
from scraping.DesiredTypes  import CarListing
import json
import re
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import attrs

plt.rcParams["figure.figsize"] = (25, 10)

# %%
df = pd.read_csv("data/results_parsed.csv")

# %%
df.describe()
# Out:
#         Unnamed: 0            id           cena  rok_produkcji      przebieg  \
# count  1016.000000  1.016000e+03    1016.000000    1016.000000  1.016000e+03
# mean    507.500000  1.019924e+09   22272.312992    2001.112205  2.780712e+05
# std     293.438239  3.326610e+07   25692.160920       7.067250  1.863785e+05
# min       0.000000  6.735680e+08     300.000000    1900.000000  1.000000e+00
# 25%     253.750000  1.021703e+09    9900.000000    1998.000000  2.222220e+05
# 50%     507.500000  1.031222e+09   15999.000000    2001.000000  2.900000e+05
# 75%     761.250000  1.033847e+09   27000.000000    2005.000000  3.465000e+05
# max    1015.000000  1.035716e+09  350000.000000    2025.000000  4.700000e+06
#
#          pojemnosc         moc
# count   929.000000  921.000000
# mean   2462.335845  193.482085
# std     730.984065   63.675621
# min       1.000000    1.000000
# 25%    1998.000000  150.000000
# 50%    2500.000000  192.000000
# 75%    2998.000000  231.000000
# ...

# %%
plt.hist(df["cena"], bins=30)
plt.title("Cena")
plt.show()
